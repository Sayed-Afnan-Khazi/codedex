# %% [markdown]
# ## Vibes - Checking the vibes of a movie to decide whether or not to watch it

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer

# %%
# reviews = [
#     "Absolutely loved the action sequences! A must-watch for Marvel fans.",
#     "The storyline felt a bit rushed, but the performances were top-notch.",
#     "Chris Evans' absence is definitely felt, but the new direction is interesting.",
#     "The movie had some great moments, but overall it lacked emotional depth.",
#     "A fantastic addition to the MCU with stunning visuals and great character arcs!",
#     "Disappointed with the weak villain and predictable plot twists.",
#     "Marvel has done it again! This film exceeded my expectations.",
#     "Too much CGI and not enough character development for my taste.",
#     "Loved the chemistry between the lead characters and the engaging story!",
#     "The pacing was inconsistent, making some parts feel slow and others rushed.",
#     "One of the best Captain America movies yet! The action was insane.",
#     "Felt like a filler movie rather than a major installment in the MCU.",
#     "The fight scenes were well-choreographed, but the script was lacking.",
#     "Great mix of action, humor, and emotion. Definitely worth watching!",
#     "A forgettable entry in the franchise. Lacked the impact of previous films."
# ]

# labels = [
#     "positive", "negative", "negative", "negative", "positive",
#     "negative", "positive", "negative", "positive", "negative",
#     "positive", "negative", "negative", "positive", "negative"
# ]

reviews = [
    "An epic conclusion to Nolan's Batman trilogy! Absolutely breathtaking.",
    "The storytelling and action sequences were phenomenal. A masterpiece!",
    "Bane was a terrifying villain, but the movie lacked the depth of The Dark Knight.",
    "The visuals, soundtrack, and performances were top-tier. Nolan delivers again!",
    "A satisfying end to the trilogy, but some plot points felt a bit forced.",
    "Christian Bale and Tom Hardy were outstanding! A must-watch for Batman fans.",
    "The action was intense, and the emotional weight of the story was powerful.",
    "Loved how they wrapped up Bruce Wayne’s journey. A near-perfect ending.",
    "The pacing was a bit uneven, but the overall experience was thrilling!",
    "Hans Zimmer’s score was legendary, elevating the entire film.",
    "One of the best superhero movies ever made! Dark, emotional, and gripping.",
    "Some scenes felt a bit unrealistic, but the film was still very entertaining.",
    "Anne Hathaway as Catwoman was fantastic, adding a great dynamic to the film.",
    "The IMAX experience made it even better! Every frame was visually stunning.",
    "A brilliant film that captures the essence of Batman. A fitting farewell to the trilogy."
]

labels = [
    "positive", "positive", "negative", "positive", "negative",
    "positive", "positive", "positive", "negative", "positive",
    "positive", "negative", "positive", "positive", "positive"
]

# %%
import matplotlib.pyplot as plt

# Plot the labels
plt.hist(labels, bins=3, edgecolor='black')
plt.xlabel('Sentiment')
plt.ylabel('Frequency')
plt.title('Distribution of Sentiments')
plt.show()

# %%
vectorizer = CountVectorizer()
x = vectorizer.fit_transform(reviews)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,labels,test_size=0.2)

# %%
model = MultinomialNB()
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_pred=y_pred,y_true=y_test)
accuracy
# Out:
# 0.3333333333333333

# %%
if accuracy > 0.8:
    print("Book tickets!!")
else:
    print("Needs more work")
# Out:
# Needs more work
